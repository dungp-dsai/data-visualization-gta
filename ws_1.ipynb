# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import gaussian_kde

# %%
# Data
barchart_data = [10, 15, 20, 5]
barchart_labels = ["Mar", "Apr", "May", "Jun"]

# Create a bar chart
plt.bar(barchart_labels, barchart_data, color='red', edgecolor='blue')

# Add labels and title
plt.xlabel("Month")
plt.ylabel("Sales Revenue")
plt.title("Revenue chart")

# Display the chart
plt.show()

# %% [markdown]
# ## Try it: Column / Bar Chart
#
# 1. Change the bar colour to `'green'`.
# 2. Change the title to `"Monthly Sales"`.
# 3. Add a new month: add `July` monthly sales to the chart (Decide the amount to whatever you want)
# 4. Reduce the width of the bar
# 5. Add value labels on top of each bar using a loop with `plt.text(...)`.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `color='green'`
# 2. `plt.title("Monthly Sales")`
# 3. `barchart_data = [10, 15, 20, 5, 25]` and `barchart_labels = ["Mar", "Apr", "May", "Jun", "Jul"]`
# 4. `plt.bar(barchart_labels, barchart_data, color='red', edgecolor='blue', width=0.5)`
# 5. Example:
# ```python
# for i, v in enumerate(barchart_data):
#     plt.text(i, v + 0.5, str(v), ha='center')
# ```
#
# </details>

# %%
# Data
barchart_data = [10, 15, 20, 5, 25]
barchart_labels = ["Mar", "Apr", "May", "Jun", "July"]

# Create a bar chart
plt.bar(barchart_labels, barchart_data, color='green', edgecolor='blue', width=0.5)

# Add labels and title
plt.xlabel("Month")
plt.ylabel("Sales Revenue")
plt.title("Monthly sales")

for i, v in enumerate(barchart_data):
    plt.text(i, v + 0.5, str(v), ha='center')

# Display the chart
plt.show()

# %%
# Create a horizontal bar chart
plt.barh(barchart_labels, barchart_data, color='red', edgecolor='blue')

# Add labels and title
plt.xlabel("Month")
plt.ylabel("Sales Revenue")
plt.title("Revenue chart")

# Display the chart
plt.show()

# %% [markdown]
# ## Try it: Horizontal Bar Chart
#
# 1. Change bar's border color to `'black'`.
# 2. Correct the x and y label for the chart (x is Sales Revenue and y is Month)
# 3. Change the bar colour to `'orange'`.
# 4. Sort the bars from largest to smallest before plotting (hint: sort both lists together).
# 5. Add gridlines on the x-axis only with `plt.grid(axis='x', linestyle='--', alpha=0.5)`.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `edgecolor='black'`
# 2. `plt.xlabel("Sales Revenue")` and `plt.ylabel("Month")`
# 3. `color='orange'`
# 4. Example:
# ```python
# pairs = sorted(zip(barchart_data, barchart_labels), reverse=True)
# barchart_data_sorted, barchart_labels_sorted = zip(*pairs)
# plt.barh(barchart_labels_sorted, barchart_data_sorted, color='red', edgecolor='blue')
# ```
# 5. `plt.grid(axis='x', linestyle='--', alpha=0.5)` before `plt.show()`
#
# </details>

# %%
# Create a horizontal bar chart
plt.barh(barchart_labels, barchart_data, color='red', edgecolor='blue')

# Add labels and title
plt.xlabel("Month")
plt.ylabel("Sales Revenue")
plt.title("Revenue chart")

# Display the chart
plt.show()

# %%
# Create a horizontal bar chart
pairs = sorted(zip(barchart_data, barchart_labels), reverse=True)
barchart_data_sorted, barchart_labels_sorted = zip(*pairs)

plt.barh(barchart_labels_sorted, barchart_data_sorted, color='orange', edgecolor='black')

# Add labels and title
plt.xlabel("Sales Revenue")
plt.ylabel("Month")
plt.title("Revenue chart")

plt.grid(axis='x', linestyle='--', alpha=0.5)
# Display the chart
plt.show()

# %%
###### Stacked Bar Chart
# Create the input vectors
colors = ["green", "orange", "brown"]
months = ["Mar", "Apr", "May", "Jun", "Jul"]
regions = ["East", "West", "North"]

# Create the matrix of the values
Values = np.array([
    [2, 9, 3, 11, 9],
    [4, 8, 7, 3, 12],
    [5, 2, 8, 10, 11]
])

# Plot the stacked bar chart
plt.barh(months, Values[0], color=colors[0])
plt.barh(months, Values[1], left=Values[0], color=colors[1])
plt.barh(months, Values[2], left=Values[0] + Values[1], color=colors[2])

# Add labels and title
plt.xlabel("Revenue")
plt.ylabel("Month")
plt.title("Sales Revenue")

# Add legend
plt.legend(regions, loc="lower right", fontsize=13)

# Display the chart
plt.show()

# %% [markdown]
# ## Try it: Stacked Bar Chart
#
# 1. Change the first colour from `"green"` to `"teal"`.
# 2. Change the title to `"Revenue by Region"`.
# 3. Move the legend to the upper right: `loc="upper right"`.
# 4. Add a new month `"Aug"` with values `6, 9, 4` for East/West/North (extend `months` and each row of `Values`).
# 5. Convert this to a **vertical** stacked bar chart using `plt.bar` instead of `plt.barh` (use `bottom=` instead of `left=`).
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `colors = ["teal", "orange", "brown"]`
# 2. `plt.title("Revenue by Region")`
# 3. `plt.legend(regions, loc="upper right", fontsize=13)`
# 4. `months = [..., "Aug"]` and
# ```python
# Values = np.array([
#     [2, 9, 3, 11, 9, 6],
#     [4, 8, 7, 3, 12, 9],
#     [5, 2, 8, 10, 11, 4]
# ])
# ```
# 5. Example:
# ```python
# plt.bar(months, Values[0], color=colors[0])
# plt.bar(months, Values[1], bottom=Values[0], color=colors[1])
# plt.bar(months, Values[2], bottom=Values[0] + Values[1], color=colors[2])
# plt.xlabel("Month")
# plt.ylabel("Revenue")
# ```
#
# </details>

# %%
##### Pie Chart
# Data
slices = [10, 15, 10, 5, 8]
labels = ["ON", "QUE", "SK", "MAN", "BC"]

# Create the pie chart
plt.pie(slices, labels=labels, autopct='%1.1f%%')
plt.title("Sales by Province")
plt.show()

# %% [markdown]
# ## Try it: Pie Chart
#
# 1. Change the title to `"Provincial Sales Share"`.
# 2. Add `startangle=90` so the first slice starts at the top.
# 3. Explode the largest slice (ON is not largest — QUE is): use `explode=(0, 0.1, 0, 0, 0)`.
# 4. Remove percentage labels by deleting `autopct='%1.1f%%'`.
# 5. Add a legend with `plt.legend(labels, loc='best')` and set `wedgeprops={'edgecolor': 'white'}`.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `plt.title("Provincial Sales Share")`
# 2. `plt.pie(slices, labels=labels, autopct='%1.1f%%', startangle=90)`
# 3. `plt.pie(slices, labels=labels, autopct='%1.1f%%', explode=(0, 0.1, 0, 0, 0))`
# 4. `plt.pie(slices, labels=labels)`
# 5. Example:
# ```python
# plt.pie(slices, labels=None, autopct='%1.1f%%', wedgeprops={'edgecolor': 'white'})
# plt.legend(labels, loc='best')
# plt.title("Sales by Province")
# plt.show()
# ```
#
# </details>

# %%
##### Boxplot
# Generate some normally distributed univariate data
np.random.seed(1)
distr_data = np.random.normal(20.5, 5.5, 1000)

# Basic boxplot
plt.boxplot(distr_data)
plt.show()

# Boxplot with notches
plt.boxplot(distr_data, notch=True)
plt.show()

# %% [markdown]
# ## Try it: Boxplot
#
# 1. Change the random seed from `1` to `42` and re-run — does the plot change?
# 2. Change the sample size from `1000` to `100` and compare the boxplots.
# 3. Add a title `"Sale Amount Distribution"` to the notched boxplot.
# 4. Make the plot horizontal with `vert=False`.
# 5. Create side-by-side boxplots of two samples: `distr_data` and `np.random.normal(25, 4, 1000)`.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `np.random.seed(42)` — yes, the distribution (and plot) changes.
# 2. `distr_data = np.random.normal(20.5, 5.5, 100)` — more variable / less smooth whiskers.
# 3. `plt.title("Sale Amount Distribution")`
# 4. `plt.boxplot(distr_data, notch=True, vert=False)`
# 5. Example:
# ```python
# distr_data2 = np.random.normal(25, 4, 1000)
# plt.boxplot([distr_data, distr_data2], labels=['A', 'B'])
# plt.show()
# ```
#
# </details>

# %%
##### Histogram
# Basic histogram
plt.hist(distr_data)
plt.show()

# Histogram with a different number of bins
plt.hist(distr_data, bins=20)
plt.show()

# %% [markdown]
# ## Try it: Histogram
#
# 1. Change `bins=20` to `bins=5` and observe how the shape changes.
# 2. Add axis labels: x = `"Sale Amount"`, y = `"Frequency"`.
# 3. Colour the bars `'skyblue'` with black edges: `color='skyblue', edgecolor='black'`.
# 4. Set `density=True` so the y-axis shows a density instead of counts.
# 5. Overlay a vertical line at the mean using `plt.axvline(np.mean(distr_data), color='red', linestyle='--')`.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `plt.hist(distr_data, bins=5)` — fewer, wider bars.
# 2. `plt.xlabel("Sale Amount")` and `plt.ylabel("Frequency")`
# 3. `plt.hist(distr_data, bins=20, color='skyblue', edgecolor='black')`
# 4. `plt.hist(distr_data, bins=20, density=True)`
# 5. Example:
# ```python
# plt.hist(distr_data, bins=20, color='skyblue', edgecolor='black')
# plt.axvline(np.mean(distr_data), color='red', linestyle='--')
# plt.show()
# ```
#
# </details>

# %%
##### Density Plot
# Generate density plot
density = gaussian_kde(distr_data)
x = np.linspace(min(distr_data), max(distr_data), 1000)
plt.plot(x, density(x), label="Density")
plt.fill_between(x, density(x), color="red", edgecolor="blue")
plt.title("Sale Amount Distribution")
plt.show()

# %% [markdown]
# ## Try it: Density Plot
#
# 1. Change the fill colour from `"red"` to `"lightgreen"`.
# 2. Change the title to `"Estimated Density of Sales"`.
# 3. Add axis labels: x = `"Sale Amount"`, y = `"Density"`.
# 4. Plot **only the outline** (comment out / remove `plt.fill_between(...)`).
# 5. Overlay the density of a second sample (`np.random.normal(30, 3, 1000)`) on the same axes in a different colour.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `color="lightgreen"` in `fill_between`
# 2. `plt.title("Estimated Density of Sales")`
# 3. `plt.xlabel("Sale Amount")` and `plt.ylabel("Density")`
# 4. Keep `plt.plot(...)` and remove `plt.fill_between(...)`
# 5. Example:
# ```python
# distr_data2 = np.random.normal(30, 3, 1000)
# density2 = gaussian_kde(distr_data2)
# x2 = np.linspace(min(distr_data2), max(distr_data2), 1000)
# plt.plot(x, density(x), label="Sample 1")
# plt.plot(x2, density2(x2), label="Sample 2")
# plt.legend()
# plt.show()
# ```
#
# </details>

# %%
##### Beeswarm Plot
# Beeswarm plot
sns.swarmplot(distr_data)
plt.show()

# Customize orientation, color, and symbol
sns.swarmplot(distr_data, color='red', marker='^', size=4, orient='h')
plt.show()

# %% [markdown]
# ## Try it: Beeswarm Plot
#
# 1. Change the marker from `'^'` to `'o'` in the customized plot.
# 2. Change `size=4` to `size=2` (smaller points).
# 3. Add a title `"Individual Sale Amounts"`.
# 4. Switch `orient='h'` to `orient='v'` (or remove `orient`) and compare layouts.
# 5. Plot only the first 200 points (`distr_data[:200]`) to reduce overlap / warnings.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `marker='o'`
# 2. `size=2`
# 3. `plt.title("Individual Sale Amounts")`
# 4. `sns.swarmplot(distr_data, color='red', marker='^', size=4, orient='v')` — vertical stack of points.
# 5. `sns.swarmplot(distr_data[:200], color='red', marker='^', size=4, orient='h')`
#
# </details>

# %%
##### Violin Plot
# Load the dataset from the GitHub URL
url = "https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/datasets/ToothGrowth.csv"
data = pd.read_csv(url)

# Convert 'dose' to a categorical variable
data['dose'] = data['dose'].astype('category')

# Prepare the data for violin plot
grouped_data = [group['len'].values for _, group in data.groupby('dose')]

# Create the violin plot
plt.violinplot(grouped_data, showmeans=False, showmedians=True)

# Add boxplot
plt.boxplot(grouped_data, positions=[1, 2, 3], widths=0.1)

# Add dotplot (scatter plot for individual points)
for i, group in enumerate(grouped_data, start=1):
    plt.scatter([i] * len(group), group, color='black', s=5, alpha=0.6)

# Customize axis labels
plt.xticks([1, 2, 3], ['0.5', '1.0', '2.0'])
plt.xlabel('Dose')
plt.ylabel('Tooth Length')
plt.title('Violin Plot of Tooth Growth by Dose')
plt.show()

# %% [markdown]
# ## Try it: Violin Plot
#
# 1. Change the title to `"Tooth Length vs Dose"`.
# 2. Change the x-tick labels to `['Low', 'Medium', 'High']`.
# 3. Make the individual points blue instead of black (`color='blue'`).
# 4. Remove the boxplot overlay (comment out or delete the `plt.boxplot(...)` line) and re-run.
# 5. Change `showmedians=True` to `showmeans=True` in `violinplot` and describe what changed on the plot.
#
# <details>
# <summary>Answers (instructor)</summary>
#
# 1. `plt.title('Tooth Length vs Dose')`
# 2. `plt.xticks([1, 2, 3], ['Low', 'Medium', 'High'])`
# 3. In the scatter loop: `color='blue'`
# 4. Comment out / delete `plt.boxplot(grouped_data, positions=[1, 2, 3], widths=0.1)` — only violin + dots remain.
# 5. `plt.violinplot(grouped_data, showmeans=True, showmedians=False)` — mean marker is shown instead of the median.
#
# </details>
